# %% [markdown]
# <a href="https://colab.research.google.com/github/crisdavid3335/analytics_with_KERAS/blob/main/StoreSalesTimeSeriesForecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importamos las librerías a utilizar
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

import xgboost as xgb
from xgboost import XGBRegressor

import tensorflow as tf
import keras 
from keras import layers
from keras.losses import mean_squared_error

from datetime import date, datetime
import time
import calendar

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargamos los datos
train = pd.read_csv('/content/drive/MyDrive/Proyectos/Store Sales - Time Series Forecasting/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Proyectos/Store Sales - Time Series Forecasting/test.csv')
sub = pd.read_csv('/content/drive/MyDrive/Proyectos/Store Sales - Time Series Forecasting/sample_submission.csv')

oil = pd.read_csv('/content/drive/MyDrive/Proyectos/Store Sales - Time Series Forecasting/oil.csv')
holiday = pd.read_csv('/content/drive/MyDrive/Proyectos/Store Sales - Time Series Forecasting/holidays_events.csv')
store = pd.read_csv('/content/drive/MyDrive/Proyectos/Store Sales - Time Series Forecasting/stores.csv')
tran = pd.read_csv('/content/drive/MyDrive/Proyectos/Store Sales - Time Series Forecasting/transactions.csv')

# %%
# Procesamos los datos 

# Vamos a añadir los días de la semana, los meses, los años, el día fecha y los días de paga
def pre_train(df):
  '''
  Esta función agrega las convenciones de tiempo.
  '''
  df['date'] = df['date'].map(lambda x: date.fromisoformat(x))
  df['weekday'] = df['date'].map(lambda x: x.weekday())
  df['year'] = df['date'].map(lambda x: x.year)
  df['month'] = df['date'].map(lambda x: x.month)
  df['day'] = df['date'].map(lambda x: x.day)
  df['eomd'] = df['date'].map(lambda x: calendar.monthrange(x.year, x.month)[1])
  df['payday'] = ((df['day'] == df['eomd'])|(df['day'] == 15)).astype(int)
  df.drop(['id', 'eomd'], axis = 1, inplace=True)
  return df

train = pre_train(train)
test = pre_train(test)

# %%
# Vamos a reemplazar los valores nulos del precio del petróleo por su promedio mensual

def pre_oil(df):
  df['month'] = df['date'].map(lambda x: int(x.replace('-', '')[:6]))
  df['month_avg'] = df.groupby('month')['dcoilwtico'].transform('mean')
  df['tmp'] = df['dcoilwtico'].map(np.isnan)
  df['month_avg'] = df['tmp'] * df['month_avg']
  df['dcoilwtico'].fillna(0, inplace =True)
  df['dcoilwtico'] = df['dcoilwtico'] + df['month_avg']
  df = df.drop(['month', 'month_avg', 'tmp'], axis = 1)
  df['date'] = df['date'].map(lambda x: date.fromisoformat(x))
  return df

oil = pre_oil(oil)

# %%
# Procesamos los días feriado, vacaiones, etc.
def pre_holyday(df):
  df['date'] = df['date'].map(lambda x: date.fromisoformat(x))
  df = df[(df['transferred'] == False) & (df['type'] != 'Work day')]
  event = df[df['type'] == 'Event']
  earthquake = event[event['description'].str.startswith('Terremoto Manabi')]
  event = event[event['description'].str.startswith('Terremoto Manabi') == False]
  return df, event, earthquake

holiday, event, earthquake = pre_holyday(holiday)

# %%
# Separamos los tipos de eventos
event = event[['date', 'description']]
event.rename({'description': 'event_name'}, axis = 1, inplace=True)

earthquake = earthquake[['date', 'description']]
earthquake.rename({'description': 'earthquake'}, axis = 1, inplace=True)

h_local = holiday[holiday['locale'] == 'Local']
h_local = h_local[['date', 'locale_name', 'description']]
h_local = h_local.rename({'locale_name': 'city', 'description': 'local_holiday_name'}, axis = 1)

h_regional = holiday[holiday['locale'] == 'Regional']
h_regional = h_regional[['date', 'locale_name', 'description']]
h_regional = h_regional.rename({'locale_name' : 'state', 
                                'description': 'regional_holiday_name'}, axis = 1)

h_national = holiday[holiday['locale'] == 'National']
h_national = holiday[['date', 'description']]
h_national = h_national.rename({'description': 'national_holiday_name'}, axis = 1)

# %%
# Vamos a unir los conjuntos de datos 
def merge_tables(df):
  df = df.merge(oil, on = 'date', how = 'left')
  df = df.merge(store, on = 'store_nbr', how='left')
  df = df.merge(event, on = 'date', how='left').fillna('0')
  df = df.merge(earthquake, on = 'date', how='left').fillna('0')
  df = df.merge(h_local, on = ['date', 'city'], how='left').fillna('0')
  df = df.merge(h_regional, on = ['date', 'state'], how='left').fillna('0')
  df = df.merge(h_national, on = 'date', how='left').fillna('0')
  df = df.merge(tran, on = ['date', 'store_nbr'], how='left').fillna('0')
  return df

train = merge_tables(train)
test = merge_tables(test)

# %%
# Cambiamos el tipo de datos a decimales
train['dcoilwtico'] = train['dcoilwtico'].astype(float)
test['dcoilwtico'] = test['dcoilwtico'].astype(float)

# %%
# Codificamos las caracteristicas categoricas
cat_features = ['family', 'store_nbr', 'city', 'state', 'type', 'cluster', 
                'event_name', 'earthquake', 'local_holiday_name', 
                'regional_holiday_name', 'national_holiday_name']
for col in cat_features:
  label_enc = LabelEncoder()
  train[col] = label_enc.fit_transform(train[col])
  test[col] = label_enc.transform(test[col])

# %%
# Vamos a separar los datos de entrenamiento y validación
# Como es una serie de tiempo se debe hacer secuencial
# Seran 31 días de validación
def pre_data(df, train_date: list, valid_date: list):
  df['is_train'] = df['date'].map(lambda x: x in train_date)
  df['is_val'] = df['date'].map(lambda x: x in valid_date)
  return df

train_date = train['date'].unique()[-227: -31].tolist()
valid_date = train['date'].unique()[-31:].tolist()
train = pre_data(train, train_date, valid_date)

# %%
print(f'Los datos de entrenamiento empiezan el {min(train_date)} y terminan el {max(train_date)}.')
print(f'El periodo de prueba empieza el {min(valid_date)} y termina el {max(valid_date)}.')
# Out:
# Los datos de entrenamiento empiezan el 2017-01-01 y terminan el 2017-07-15.
# El periodo de prueba empieza el 2017-07-16 y termina el 2017-08-15.

# %%
# Generamos los conjuntos de datos y objetivos (X, y).
# Para normalizar las ventas se toma su logaritmo
y = np.log(train['sales'] + 1)

X_train = train.drop(['date', 'sales', 'year'], axis = 1)
X_test = test.drop(['date', 'year'], axis = 1).values.astype(float)

trn_idx = X_train[X_train['is_train']==True].index.tolist()
val_idx = X_train[X_train['is_val']==True].index.tolist()

X_tr = X_train.loc[trn_idx, :].drop(['is_train', 'is_val'], axis=1).values.astype(float)
X_val = X_train.loc[val_idx, :].drop(['is_train', 'is_val'], axis=1).values.astype(float)
y_tr = y[trn_idx].values.astype(float)
y_val = y[val_idx].values.astype(float)

# %%
# Construimos los modelos

# DNN
dnn_model = keras.Sequential([
                              layers.Dense(256, activation = 'relu'),
                              layers.Dropout(0.3),
                              layers.Dense(256, activation = 'relu'),
                              layers.Dropout(0.3),
                              layers.Dense(128, activation = 'relu'),
                              layers.Dense(128, activation = 'relu'),
                              layers.Dense(1)
])

dnn_model.compile(optimizer = 'adam', 
              loss = mean_squared_error,
              metrics = ['mae'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor = 'val_loss',
    mode = 'auto',    
    patience = 50,
    verbose = 0, 
    restore_best_weights = True)

# Xgboost
xgb_model = XGBRegressor(max_depth = 5, verbosity = 0, 
                         objective = 'reg:squarederror', 
                         n_estimators = 600, 
                         reg_alpha=10., subsample = 0.9963,
                         min_child_weight=47, 
                         random_state = 0)

# %%
# Entrenamos los modelos
history = dnn_model.fit(X_tr,
                    y_tr,
                    epochs = 400,
                    batch_size = 128,
                    callbacks = [early_stopping],
                    validation_data = (X_val, y_val))

xgb_model.fit(X_tr, y_tr,
              early_stopping_rounds = 100, 
              eval_set=[(X_val, y_val)])
# Out:
# Epoch 1/400
# 2785/2785 [==============================] - 25s 9ms/step - loss: 2.6027 - mae: 1.2749 - val_loss: 2.5911 - val_mae: 1.2798
# Epoch 2/400
# 2785/2785 [==============================] - 27s 10ms/step - loss: 1.8871 - mae: 1.0637 - val_loss: 2.1271 - val_mae: 1.1043
# Epoch 3/400
# 2785/2785 [==============================] - 27s 10ms/step - loss: 1.7113 - mae: 1.0000 - val_loss: 1.8531 - val_mae: 1.0129
# Epoch 4/400
# 2785/2785 [==============================] - 28s 10ms/step - loss: 1.6193 - mae: 0.9622 - val_loss: 1.7895 - val_mae: 1.0019
# Epoch 5/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.5611 - mae: 0.9366 - val_loss: 1.9574 - val_mae: 1.0301
# Epoch 6/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.5267 - mae: 0.9209 - val_loss: 1.7732 - val_mae: 0.9533
# Epoch 7/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.5037 - mae: 0.9108 - val_loss: 1.6282 - val_mae: 0.9364
# Epoch 8/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.4755 - mae: 0.8985 - val_loss: 1.6718 - val_mae: 0.9404
# Epoch 9/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.4568 - mae: 0.8897 - val_loss: 1.7084 - val_mae: 0.9476
# Epoch 10/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.4400 - mae: 0.8825 - val_loss: 1.6494 - val_mae: 0.9267
# Epoch 11/400
# 2785/2785 [==============================] - 24s 9ms/step - loss: 1.4248 - mae: 0.8754 - val_loss: 1.6302 - val_mae: 0.9046
# Epoch 12/400
# 2785/2785 [==============================] - 26s 9ms/step - loss: 1.4090 - mae: 0.8692 - val_loss: 1.7258 - val_mae: 0.9474
# Epoch 13/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.3954 - mae: 0.8629 - val_loss: 1.6707 - val_mae: 0.9210
# Epoch 14/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.3831 - mae: 0.8582 - val_loss: 1.6659 - val_mae: 0.9292
# Epoch 15/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.3757 - mae: 0.8541 - val_loss: 1.7299 - val_mae: 0.9560
# Epoch 16/400
# 2785/2785 [==============================] - 20s 7ms/step - loss: 1.3595 - mae: 0.8478 - val_loss: 1.5317 - val_mae: 0.8979
# Epoch 17/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.3535 - mae: 0.8441 - val_loss: 1.6749 - val_mae: 0.9276
# Epoch 18/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.3397 - mae: 0.8394 - val_loss: 1.5153 - val_mae: 0.9007
# Epoch 19/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.3373 - mae: 0.8369 - val_loss: 1.6898 - val_mae: 0.9259
# Epoch 20/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.3205 - mae: 0.8308 - val_loss: 1.6464 - val_mae: 0.9100
# Epoch 21/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.3081 - mae: 0.8263 - val_loss: 1.6426 - val_mae: 0.8982
# Epoch 22/400
# 2785/2785 [==============================] - 24s 9ms/step - loss: 1.3000 - mae: 0.8228 - val_loss: 1.4339 - val_mae: 0.8707
# Epoch 23/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.2922 - mae: 0.8187 - val_loss: 1.7312 - val_mae: 0.9249
# Epoch 24/400
# 2785/2785 [==============================] - 23s 8ms/step - loss: 1.2782 - mae: 0.8127 - val_loss: 1.6269 - val_mae: 0.8965
# Epoch 25/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.2716 - mae: 0.8105 - val_loss: 1.4866 - val_mae: 0.8788
# Epoch 26/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.2652 - mae: 0.8094 - val_loss: 1.5576 - val_mae: 0.8914
# Epoch 27/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.2467 - mae: 0.8015 - val_loss: 1.5926 - val_mae: 0.8789
# Epoch 28/400
# 2785/2785 [==============================] - 24s 8ms/step - loss: 1.2342 - mae: 0.7963 - val_loss: 1.4488 - val_mae: 0.8559
# Epoch 29/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.2212 - mae: 0.7922 - val_loss: 1.3953 - val_mae: 0.8343
# Epoch 30/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.2087 - mae: 0.7873 - val_loss: 1.6633 - val_mae: 0.8993
# Epoch 31/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.2014 - mae: 0.7832 - val_loss: 1.4658 - val_mae: 0.8585
# Epoch 32/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.1805 - mae: 0.7760 - val_loss: 1.3088 - val_mae: 0.8085
# Epoch 33/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.1759 - mae: 0.7740 - val_loss: 1.5130 - val_mae: 0.8575
# Epoch 34/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.1617 - mae: 0.7681 - val_loss: 1.6754 - val_mae: 0.9079
# Epoch 35/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.1399 - mae: 0.7605 - val_loss: 1.5652 - val_mae: 0.8633
# Epoch 36/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.1334 - mae: 0.7571 - val_loss: 1.6217 - val_mae: 0.8747
# Epoch 37/400
# 2785/2785 [==============================] - 20s 7ms/step - loss: 1.1167 - mae: 0.7510 - val_loss: 1.4027 - val_mae: 0.8350
# Epoch 38/400
# 2785/2785 [==============================] - 21s 7ms/step - loss: 1.1037 - mae: 0.7458 - val_loss: 1.5751 - val_mae: 0.8431
# Epoch 39/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.0847 - mae: 0.7394 - val_loss: 1.3871 - val_mae: 0.8161
# Epoch 40/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.0763 - mae: 0.7353 - val_loss: 1.7574 - val_mae: 0.8756
# Epoch 41/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 1.0709 - mae: 0.7334 - val_loss: 1.4517 - val_mae: 0.8323
# Epoch 42/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.0319 - mae: 0.7193 - val_loss: 1.9483 - val_mae: 0.9427
# Epoch 43/400
# 2785/2785 [==============================] - 21s 7ms/step - loss: 1.0275 - mae: 0.7170 - val_loss: 1.6163 - val_mae: 0.8673
# Epoch 44/400
# 2785/2785 [==============================] - 24s 8ms/step - loss: 1.0069 - mae: 0.7100 - val_loss: 1.3648 - val_mae: 0.8071
# Epoch 45/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 1.0065 - mae: 0.7087 - val_loss: 1.8054 - val_mae: 0.8914
# Epoch 46/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.9929 - mae: 0.7040 - val_loss: 1.4694 - val_mae: 0.8231
# Epoch 47/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 0.9748 - mae: 0.6971 - val_loss: 1.8803 - val_mae: 0.9040
# Epoch 48/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.9746 - mae: 0.6967 - val_loss: 1.6894 - val_mae: 0.8732
# Epoch 49/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.9777 - mae: 0.6971 - val_loss: 2.2222 - val_mae: 0.9995
# Epoch 50/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.9617 - mae: 0.6921 - val_loss: 2.1214 - val_mae: 0.9566
# Epoch 51/400
# 2785/2785 [==============================] - 23s 8ms/step - loss: 0.9643 - mae: 0.6911 - val_loss: 1.4620 - val_mae: 0.8032
# Epoch 52/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.9357 - mae: 0.6819 - val_loss: 1.7306 - val_mae: 0.8628
# Epoch 53/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.9316 - mae: 0.6792 - val_loss: 1.5940 - val_mae: 0.8340
# Epoch 54/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.9296 - mae: 0.6773 - val_loss: 2.2125 - val_mae: 0.9693
# Epoch 55/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 0.9166 - mae: 0.6733 - val_loss: 1.6747 - val_mae: 0.8510
# Epoch 56/400
# 2785/2785 [==============================] - 23s 8ms/step - loss: 0.9411 - mae: 0.6834 - val_loss: 1.8588 - val_mae: 0.8962
# Epoch 57/400
# 2785/2785 [==============================] - 21s 7ms/step - loss: 0.9044 - mae: 0.6707 - val_loss: 2.0206 - val_mae: 0.9472
# Epoch 58/400
# 2785/2785 [==============================] - 21s 7ms/step - loss: 0.8958 - mae: 0.6661 - val_loss: 1.9746 - val_mae: 0.9247
# Epoch 59/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.8952 - mae: 0.6664 - val_loss: 2.1492 - val_mae: 0.9674
# Epoch 60/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.8918 - mae: 0.6642 - val_loss: 1.7500 - val_mae: 0.8668
# Epoch 61/400
# 2785/2785 [==============================] - 27s 10ms/step - loss: 0.8904 - mae: 0.6643 - val_loss: 2.1522 - val_mae: 0.9547
# Epoch 62/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.8787 - mae: 0.6604 - val_loss: 2.2808 - val_mae: 0.9906
# Epoch 63/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.8760 - mae: 0.6594 - val_loss: 1.3497 - val_mae: 0.7834
# Epoch 64/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.8743 - mae: 0.6575 - val_loss: 1.5603 - val_mae: 0.8210
# Epoch 65/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.8616 - mae: 0.6529 - val_loss: 1.9714 - val_mae: 0.9215
# Epoch 66/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.8674 - mae: 0.6558 - val_loss: 1.9445 - val_mae: 0.9091
# Epoch 67/400
# 2785/2785 [==============================] - 23s 8ms/step - loss: 0.8597 - mae: 0.6528 - val_loss: 2.5761 - val_mae: 1.0691
# Epoch 68/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.8484 - mae: 0.6481 - val_loss: 2.2032 - val_mae: 0.9841
# Epoch 69/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.8364 - mae: 0.6447 - val_loss: 1.9831 - val_mae: 0.9062
# Epoch 70/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 0.8283 - mae: 0.6411 - val_loss: 2.3875 - val_mae: 1.0182
# Epoch 71/400
# 2785/2785 [==============================] - 20s 7ms/step - loss: 0.8305 - mae: 0.6407 - val_loss: 1.9168 - val_mae: 0.9089
# Epoch 72/400
# 2785/2785 [==============================] - 20s 7ms/step - loss: 0.8193 - mae: 0.6382 - val_loss: 2.3062 - val_mae: 1.0001
# Epoch 73/400
# 2785/2785 [==============================] - 20s 7ms/step - loss: 0.8253 - mae: 0.6389 - val_loss: 2.0611 - val_mae: 0.9726
# Epoch 74/400
# 2785/2785 [==============================] - 20s 7ms/step - loss: 0.8118 - mae: 0.6353 - val_loss: 2.2855 - val_mae: 1.0069
# Epoch 75/400
# 2785/2785 [==============================] - 21s 7ms/step - loss: 0.7915 - mae: 0.6274 - val_loss: 2.5949 - val_mae: 1.0689
# Epoch 76/400
# 2785/2785 [==============================] - 21s 7ms/step - loss: 0.7898 - mae: 0.6270 - val_loss: 2.4425 - val_mae: 1.0227
# Epoch 77/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 0.7805 - mae: 0.6237 - val_loss: 2.5856 - val_mae: 1.0658
# Epoch 78/400
# 2785/2785 [==============================] - 21s 8ms/step - loss: 0.7797 - mae: 0.6243 - val_loss: 2.3341 - val_mae: 1.0182
# Epoch 79/400
# 2785/2785 [==============================] - 20s 7ms/step - loss: 0.7723 - mae: 0.6215 - val_loss: 2.2381 - val_mae: 0.9861
# Epoch 80/400
# 2785/2785 [==============================] - 20s 7ms/step - loss: 0.8222 - mae: 0.6412 - val_loss: 1.6925 - val_mae: 0.8405
# Epoch 81/400
# 2785/2785 [==============================] - 22s 8ms/step - loss: 0.8099 - mae: 0.6379 - val_loss: 2.4171 - val_mae: 1.0475
# Epoch 82/400
# 2785/2785 [==============================] - 23s 8ms/step - loss: 0.8141 - mae: 0.6383 - val_loss: 2.3152 - val_mae: 0.9996
# [0]	validation_0-rmse:3.66022
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [1]	validation_0-rmse:3.34457
# [2]	validation_0-rmse:3.06232
# [3]	validation_0-rmse:2.81018
# [4]	validation_0-rmse:2.58469
# [5]	validation_0-rmse:2.37509
# [6]	validation_0-rmse:2.19767
# [7]	validation_0-rmse:2.04542
# [8]	validation_0-rmse:1.90746
# [9]	validation_0-rmse:1.78202
# [10]	validation_0-rmse:1.67346
# [11]	validation_0-rmse:1.58455
# [12]	validation_0-rmse:1.49842
# [13]	validation_0-rmse:1.42793
# [14]	validation_0-rmse:1.36692
# [15]	validation_0-rmse:1.31381
# [16]	validation_0-rmse:1.26379
# [17]	validation_0-rmse:1.21394
# [18]	validation_0-rmse:1.17702
# [19]	validation_0-rmse:1.14673
# [20]	validation_0-rmse:1.11129
# [21]	validation_0-rmse:1.07591
# [22]	validation_0-rmse:1.04656
# [23]	validation_0-rmse:1.01709
# [24]	validation_0-rmse:1.00096
# [25]	validation_0-rmse:0.982386
# [26]	validation_0-rmse:0.96957
# [27]	validation_0-rmse:0.953215
# [28]	validation_0-rmse:0.930045
# [29]	validation_0-rmse:0.916066
# [30]	validation_0-rmse:0.906854
# [31]	validation_0-rmse:0.900188
# [32]	validation_0-rmse:0.893036
# [33]	validation_0-rmse:0.884926
# [34]	validation_0-rmse:0.876243
# [35]	validation_0-rmse:0.867582
# [36]	validation_0-rmse:0.858668
# [37]	validation_0-rmse:0.852395
# [38]	validation_0-rmse:0.844283
# [39]	validation_0-rmse:0.840572
# [40]	validation_0-rmse:0.832532
# [41]	validation_0-rmse:0.826161
# [42]	validation_0-rmse:0.82342
# [43]	validation_0-rmse:0.816857
# [44]	validation_0-rmse:0.811434
# [45]	validation_0-rmse:0.798914
# [46]	validation_0-rmse:0.796838
# [47]	validation_0-rmse:0.793831
# [48]	validation_0-rmse:0.791663
# [49]	validation_0-rmse:0.787617
# [50]	validation_0-rmse:0.784196
# [51]	validation_0-rmse:0.782288
# [52]	validation_0-rmse:0.778938
# [53]	validation_0-rmse:0.773043
# [54]	validation_0-rmse:0.768538
# [55]	validation_0-rmse:0.767239
# [56]	validation_0-rmse:0.758855
# [57]	validation_0-rmse:0.757112
# [58]	validation_0-rmse:0.75657
# [59]	validation_0-rmse:0.75391
# [60]	validation_0-rmse:0.75037
# [61]	validation_0-rmse:0.737762
# [62]	validation_0-rmse:0.733611
# [63]	validation_0-rmse:0.732794
# [64]	validation_0-rmse:0.730074
# [65]	validation_0-rmse:0.728941
# [66]	validation_0-rmse:0.727102
# [67]	validation_0-rmse:0.726151
# [68]	validation_0-rmse:0.724476
# [69]	validation_0-rmse:0.71746
# [70]	validation_0-rmse:0.711408
# [71]	validation_0-rmse:0.70754
# [72]	validation_0-rmse:0.706636
# [73]	validation_0-rmse:0.702601
# [74]	validation_0-rmse:0.701191
# [75]	validation_0-rmse:0.693745
# [76]	validation_0-rmse:0.691673
# [77]	validation_0-rmse:0.687583
# [78]	validation_0-rmse:0.68655
# [79]	validation_0-rmse:0.680417
# [80]	validation_0-rmse:0.679895
# [81]	validation_0-rmse:0.677658
# [82]	validation_0-rmse:0.668948
# [83]	validation_0-rmse:0.663947
# [84]	validation_0-rmse:0.66254
# [85]	validation_0-rmse:0.662188
# [86]	validation_0-rmse:0.654854
# [87]	validation_0-rmse:0.649527
# [88]	validation_0-rmse:0.648254
# [89]	validation_0-rmse:0.644377
# [90]	validation_0-rmse:0.642861
# [91]	validation_0-rmse:0.641926
# [92]	validation_0-rmse:0.640344
# [93]	validation_0-rmse:0.637574
# [94]	validation_0-rmse:0.637239
# [95]	validation_0-rmse:0.636352
# [96]	validation_0-rmse:0.630765
# [97]	validation_0-rmse:0.626542
# [98]	validation_0-rmse:0.625814
# [99]	validation_0-rmse:0.622666
# [100]	validation_0-rmse:0.622065
# [101]	validation_0-rmse:0.62111
# [102]	validation_0-rmse:0.618378
# [103]	validation_0-rmse:0.614927
# [104]	validation_0-rmse:0.614256
# [105]	validation_0-rmse:0.613537
# [106]	validation_0-rmse:0.610506
# [107]	validation_0-rmse:0.610208
# [108]	validation_0-rmse:0.608955
# [109]	validation_0-rmse:0.607366
# [110]	validation_0-rmse:0.606531
# [111]	validation_0-rmse:0.605919
# [112]	validation_0-rmse:0.605858
# [113]	validation_0-rmse:0.605317
# [114]	validation_0-rmse:0.60438
# [115]	validation_0-rmse:0.603738
# [116]	validation_0-rmse:0.600865
# [117]	validation_0-rmse:0.600261
# [118]	validation_0-rmse:0.600221
# [119]	validation_0-rmse:0.599046
# [120]	validation_0-rmse:0.598606
# [121]	validation_0-rmse:0.598429
# [122]	validation_0-rmse:0.595683
# [123]	validation_0-rmse:0.592154
# [124]	validation_0-rmse:0.590375
# [125]	validation_0-rmse:0.589243
# [126]	validation_0-rmse:0.58746
# [127]	validation_0-rmse:0.586907
# [128]	validation_0-rmse:0.586505
# [129]	validation_0-rmse:0.586578
# [130]	validation_0-rmse:0.585395
# [131]	validation_0-rmse:0.583192
# [132]	validation_0-rmse:0.582894
# [133]	validation_0-rmse:0.582306
# [134]	validation_0-rmse:0.582317
# [135]	validation_0-rmse:0.581654
# [136]	validation_0-rmse:0.580179
# [137]	validation_0-rmse:0.579572
# [138]	validation_0-rmse:0.578737
# [139]	validation_0-rmse:0.578224
# [140]	validation_0-rmse:0.577109
# [141]	validation_0-rmse:0.576109
# [142]	validation_0-rmse:0.575551
# [143]	validation_0-rmse:0.575401
# [144]	validation_0-rmse:0.575116
# [145]	validation_0-rmse:0.575027
# [146]	validation_0-rmse:0.574931
# [147]	validation_0-rmse:0.57417
# [148]	validation_0-rmse:0.57297
# [149]	validation_0-rmse:0.572532
# [150]	validation_0-rmse:0.572011
# [151]	validation_0-rmse:0.570831
# [152]	validation_0-rmse:0.570365
# [153]	validation_0-rmse:0.568361
# [154]	validation_0-rmse:0.567893
# [155]	validation_0-rmse:0.5676
# [156]	validation_0-rmse:0.567102
# [157]	validation_0-rmse:0.566781
# [158]	validation_0-rmse:0.566394
# [159]	validation_0-rmse:0.566071
# [160]	validation_0-rmse:0.5652
# [161]	validation_0-rmse:0.564839
# [162]	validation_0-rmse:0.564127
# [163]	validation_0-rmse:0.563273
# [164]	validation_0-rmse:0.56269
# [165]	validation_0-rmse:0.559904
# [166]	validation_0-rmse:0.559104
# [167]	validation_0-rmse:0.556932
# [168]	validation_0-rmse:0.55623
# [169]	validation_0-rmse:0.555544
# [170]	validation_0-rmse:0.553906
# [171]	validation_0-rmse:0.552877
# [172]	validation_0-rmse:0.552226
# [173]	validation_0-rmse:0.55199
# [174]	validation_0-rmse:0.551705
# [175]	validation_0-rmse:0.551586
# [176]	validation_0-rmse:0.550608
# [177]	validation_0-rmse:0.549132
# [178]	validation_0-rmse:0.548177
# [179]	validation_0-rmse:0.547711
# [180]	validation_0-rmse:0.54692
# [181]	validation_0-rmse:0.546622
# [182]	validation_0-rmse:0.546204
# [183]	validation_0-rmse:0.545521
# [184]	validation_0-rmse:0.545388
# [185]	validation_0-rmse:0.543694
# [186]	validation_0-rmse:0.543608
# [187]	validation_0-rmse:0.543047
# [188]	validation_0-rmse:0.542704
# [189]	validation_0-rmse:0.542548
# [190]	validation_0-rmse:0.542201
# [191]	validation_0-rmse:0.54186
# [192]	validation_0-rmse:0.541207
# [193]	validation_0-rmse:0.540681
# [194]	validation_0-rmse:0.540121
# [195]	validation_0-rmse:0.539512
# [196]	validation_0-rmse:0.539368
# [197]	validation_0-rmse:0.539235
# [198]	validation_0-rmse:0.53902
# [199]	validation_0-rmse:0.538975
# [200]	validation_0-rmse:0.538405
# [201]	validation_0-rmse:0.53738
# [202]	validation_0-rmse:0.537207
# [203]	validation_0-rmse:0.537145
# [204]	validation_0-rmse:0.536249
# [205]	validation_0-rmse:0.535726
# [206]	validation_0-rmse:0.53542
# [207]	validation_0-rmse:0.535177
# [208]	validation_0-rmse:0.535043
# [209]	validation_0-rmse:0.534754
# [210]	validation_0-rmse:0.533957
# [211]	validation_0-rmse:0.533861
# [212]	validation_0-rmse:0.533516
# [213]	validation_0-rmse:0.533058
# [214]	validation_0-rmse:0.53114
# [215]	validation_0-rmse:0.530677
# [216]	validation_0-rmse:0.530073
# [217]	validation_0-rmse:0.529723
# [218]	validation_0-rmse:0.529526
# [219]	validation_0-rmse:0.529435
# [220]	validation_0-rmse:0.528695
# [221]	validation_0-rmse:0.527164
# [222]	validation_0-rmse:0.526556
# [223]	validation_0-rmse:0.526446
# [224]	validation_0-rmse:0.525985
# [225]	validation_0-rmse:0.525838
# [226]	validation_0-rmse:0.525443
# [227]	validation_0-rmse:0.525407
# [228]	validation_0-rmse:0.525277
# [229]	validation_0-rmse:0.52511
# [230]	validation_0-rmse:0.524084
# [231]	validation_0-rmse:0.52364
# [232]	validation_0-rmse:0.523504
# [233]	validation_0-rmse:0.523231
# [234]	validation_0-rmse:0.522673
# [235]	validation_0-rmse:0.522457
# [236]	validation_0-rmse:0.522367
# [237]	validation_0-rmse:0.522192
# [238]	validation_0-rmse:0.521998
# [239]	validation_0-rmse:0.520772
# [240]	validation_0-rmse:0.520778
# [241]	validation_0-rmse:0.52061
# [242]	validation_0-rmse:0.520252
# [243]	validation_0-rmse:0.520057
# [244]	validation_0-rmse:0.519493
# [245]	validation_0-rmse:0.519475
# [246]	validation_0-rmse:0.519387
# [247]	validation_0-rmse:0.51869
# [248]	validation_0-rmse:0.518238
# [249]	validation_0-rmse:0.518116
# [250]	validation_0-rmse:0.517772
# [251]	validation_0-rmse:0.517709
# [252]	validation_0-rmse:0.517601
# [253]	validation_0-rmse:0.517472
# [254]	validation_0-rmse:0.517419
# [255]	validation_0-rmse:0.517349
# [256]	validation_0-rmse:0.517092
# [257]	validation_0-rmse:0.517017
# [258]	validation_0-rmse:0.516795
# [259]	validation_0-rmse:0.516588
# [260]	validation_0-rmse:0.516186
# [261]	validation_0-rmse:0.515743
# [262]	validation_0-rmse:0.515327
# [263]	validation_0-rmse:0.515236
# [264]	validation_0-rmse:0.514826
# [265]	validation_0-rmse:0.51471
# [266]	validation_0-rmse:0.514464
# [267]	validation_0-rmse:0.514253
# [268]	validation_0-rmse:0.514032
# [269]	validation_0-rmse:0.513584
# [270]	validation_0-rmse:0.513399
# [271]	validation_0-rmse:0.512794
# [272]	validation_0-rmse:0.512694
# [273]	validation_0-rmse:0.511715
# [274]	validation_0-rmse:0.51141
# [275]	validation_0-rmse:0.511396
# [276]	validation_0-rmse:0.511325
# [277]	validation_0-rmse:0.511085
# [278]	validation_0-rmse:0.510623
# [279]	validation_0-rmse:0.510571
# [280]	validation_0-rmse:0.510575
# [281]	validation_0-rmse:0.510455
# [282]	validation_0-rmse:0.510413
# [283]	validation_0-rmse:0.510179
# [284]	validation_0-rmse:0.509878
# [285]	validation_0-rmse:0.509645
# [286]	validation_0-rmse:0.509547
# [287]	validation_0-rmse:0.509512
# [288]	validation_0-rmse:0.509265
# [289]	validation_0-rmse:0.509203
# [290]	validation_0-rmse:0.508995
# [291]	validation_0-rmse:0.508892
# [292]	validation_0-rmse:0.508816
# [293]	validation_0-rmse:0.508643
# [294]	validation_0-rmse:0.507846
# [295]	validation_0-rmse:0.5076
# [296]	validation_0-rmse:0.507327
# [297]	validation_0-rmse:0.507212
# [298]	validation_0-rmse:0.50723
# [299]	validation_0-rmse:0.507078
# [300]	validation_0-rmse:0.507085
# [301]	validation_0-rmse:0.506775
# [302]	validation_0-rmse:0.506269
# [303]	validation_0-rmse:0.506175
# [304]	validation_0-rmse:0.506211
# [305]	validation_0-rmse:0.506191
# [306]	validation_0-rmse:0.50612
# [307]	validation_0-rmse:0.506047
# [308]	validation_0-rmse:0.505691
# [309]	validation_0-rmse:0.505719
# [310]	validation_0-rmse:0.50535
# [311]	validation_0-rmse:0.505225
# [312]	validation_0-rmse:0.505132
# [313]	validation_0-rmse:0.505135
# [314]	validation_0-rmse:0.504918
# [315]	validation_0-rmse:0.504586
# [316]	validation_0-rmse:0.504535
# [317]	validation_0-rmse:0.504237
# [318]	validation_0-rmse:0.503798
# [319]	validation_0-rmse:0.503674
# [320]	validation_0-rmse:0.503429
# [321]	validation_0-rmse:0.503167
# [322]	validation_0-rmse:0.503022
# [323]	validation_0-rmse:0.503013
# [324]	validation_0-rmse:0.502728
# [325]	validation_0-rmse:0.50243
# [326]	validation_0-rmse:0.502067
# [327]	validation_0-rmse:0.502084
# [328]	validation_0-rmse:0.501901
# [329]	validation_0-rmse:0.501617
# [330]	validation_0-rmse:0.501597
# [331]	validation_0-rmse:0.501552
# [332]	validation_0-rmse:0.501363
# [333]	validation_0-rmse:0.501283
# [334]	validation_0-rmse:0.501228
# [335]	validation_0-rmse:0.500959
# [336]	validation_0-rmse:0.500527
# [337]	validation_0-rmse:0.500558
# [338]	validation_0-rmse:0.500368
# [339]	validation_0-rmse:0.500025
# [340]	validation_0-rmse:0.499783
# [341]	validation_0-rmse:0.499559
# [342]	validation_0-rmse:0.499287
# [343]	validation_0-rmse:0.498861
# [344]	validation_0-rmse:0.498589
# [345]	validation_0-rmse:0.498195
# [346]	validation_0-rmse:0.497879
# [347]	validation_0-rmse:0.497843
# [348]	validation_0-rmse:0.497625
# [349]	validation_0-rmse:0.497275
# [350]	validation_0-rmse:0.49728
# [351]	validation_0-rmse:0.497113
# [352]	validation_0-rmse:0.497118
# [353]	validation_0-rmse:0.497091
# [354]	validation_0-rmse:0.496896
# [355]	validation_0-rmse:0.496906
# [356]	validation_0-rmse:0.496858
# [357]	validation_0-rmse:0.496253
# [358]	validation_0-rmse:0.496076
# [359]	validation_0-rmse:0.495994
# [360]	validation_0-rmse:0.495935
# [361]	validation_0-rmse:0.495849
# [362]	validation_0-rmse:0.495865
# [363]	validation_0-rmse:0.495787
# [364]	validation_0-rmse:0.495481
# [365]	validation_0-rmse:0.495362
# [366]	validation_0-rmse:0.495291
# [367]	validation_0-rmse:0.495086
# [368]	validation_0-rmse:0.495008
# [369]	validation_0-rmse:0.495001
# [370]	validation_0-rmse:0.494854
# [371]	validation_0-rmse:0.494838
# [372]	validation_0-rmse:0.494799
# [373]	validation_0-rmse:0.494739
# [374]	validation_0-rmse:0.494622
# [375]	validation_0-rmse:0.494688
# [376]	validation_0-rmse:0.494632
# [377]	validation_0-rmse:0.494398
# [378]	validation_0-rmse:0.49439
# [379]	validation_0-rmse:0.494349
# [380]	validation_0-rmse:0.494156
# [381]	validation_0-rmse:0.494123
# [382]	validation_0-rmse:0.493994
# [383]	validation_0-rmse:0.493998
# [384]	validation_0-rmse:0.493942
# [385]	validation_0-rmse:0.493889
# [386]	validation_0-rmse:0.493553
# [387]	validation_0-rmse:0.493485
# [388]	validation_0-rmse:0.493348
# [389]	validation_0-rmse:0.493123
# [390]	validation_0-rmse:0.49305
# [391]	validation_0-rmse:0.493017
# [392]	validation_0-rmse:0.493026
# [393]	validation_0-rmse:0.492817
# [394]	validation_0-rmse:0.492691
# [395]	validation_0-rmse:0.492656
# [396]	validation_0-rmse:0.492618
# [397]	validation_0-rmse:0.492464
# [398]	validation_0-rmse:0.492432
# [399]	validation_0-rmse:0.492139
# [400]	validation_0-rmse:0.491954
# [401]	validation_0-rmse:0.491934
# [402]	validation_0-rmse:0.49189
# [403]	validation_0-rmse:0.491868
# [404]	validation_0-rmse:0.491547
# [405]	validation_0-rmse:0.491398
# [406]	validation_0-rmse:0.491127
# [407]	validation_0-rmse:0.491117
# [408]	validation_0-rmse:0.490944
# [409]	validation_0-rmse:0.490864
# [410]	validation_0-rmse:0.490813
# [411]	validation_0-rmse:0.490765
# [412]	validation_0-rmse:0.490609
# [413]	validation_0-rmse:0.49065
# [414]	validation_0-rmse:0.490512
# [415]	validation_0-rmse:0.490412
# [416]	validation_0-rmse:0.490254
# [417]	validation_0-rmse:0.490109
# [418]	validation_0-rmse:0.489891
# [419]	validation_0-rmse:0.489916
# [420]	validation_0-rmse:0.489836
# [421]	validation_0-rmse:0.489583
# [422]	validation_0-rmse:0.489189
# [423]	validation_0-rmse:0.489248
# [424]	validation_0-rmse:0.489092
# [425]	validation_0-rmse:0.488877
# [426]	validation_0-rmse:0.488799
# [427]	validation_0-rmse:0.488686
# [428]	validation_0-rmse:0.488322
# [429]	validation_0-rmse:0.487941
# [430]	validation_0-rmse:0.487977
# [431]	validation_0-rmse:0.487821
# [432]	validation_0-rmse:0.487854
# [433]	validation_0-rmse:0.487831
# [434]	validation_0-rmse:0.48777
# [435]	validation_0-rmse:0.487764
# [436]	validation_0-rmse:0.487593
# [437]	validation_0-rmse:0.487602
# [438]	validation_0-rmse:0.487612
# [439]	validation_0-rmse:0.48751
# [440]	validation_0-rmse:0.487509
# [441]	validation_0-rmse:0.487557
# [442]	validation_0-rmse:0.487381
# [443]	validation_0-rmse:0.487186
# [444]	validation_0-rmse:0.486926
# [445]	validation_0-rmse:0.486906
# [446]	validation_0-rmse:0.486831
# [447]	validation_0-rmse:0.486619
# [448]	validation_0-rmse:0.48668
# [449]	validation_0-rmse:0.486362
# [450]	validation_0-rmse:0.48624
# [451]	validation_0-rmse:0.485899
# [452]	validation_0-rmse:0.485875
# [453]	validation_0-rmse:0.485721
# [454]	validation_0-rmse:0.48554
# [455]	validation_0-rmse:0.485551
# [456]	validation_0-rmse:0.485436
# [457]	validation_0-rmse:0.484864
# [458]	validation_0-rmse:0.48478
# [459]	validation_0-rmse:0.484547
# [460]	validation_0-rmse:0.484173
# [461]	validation_0-rmse:0.483966
# [462]	validation_0-rmse:0.4839
# [463]	validation_0-rmse:0.483756
# [464]	validation_0-rmse:0.483554
# [465]	validation_0-rmse:0.48341
# [466]	validation_0-rmse:0.483276
# [467]	validation_0-rmse:0.483192
# [468]	validation_0-rmse:0.483224
# [469]	validation_0-rmse:0.483199
# [470]	validation_0-rmse:0.483189
# [471]	validation_0-rmse:0.48312
# [472]	validation_0-rmse:0.483129
# [473]	validation_0-rmse:0.483121
# [474]	validation_0-rmse:0.482979
# [475]	validation_0-rmse:0.482957
# [476]	validation_0-rmse:0.482778
# [477]	validation_0-rmse:0.482468
# [478]	validation_0-rmse:0.482273
# [479]	validation_0-rmse:0.482111
# [480]	validation_0-rmse:0.482058
# [481]	validation_0-rmse:0.481905
# [482]	validation_0-rmse:0.481944
# [483]	validation_0-rmse:0.481764
# [484]	validation_0-rmse:0.481682
# [485]	validation_0-rmse:0.481538
# [486]	validation_0-rmse:0.481491
# [487]	validation_0-rmse:0.481347
# [488]	validation_0-rmse:0.481214
# [489]	validation_0-rmse:0.481184
# [490]	validation_0-rmse:0.48105
# [491]	validation_0-rmse:0.481025
# [492]	validation_0-rmse:0.480948
# [493]	validation_0-rmse:0.480886
# [494]	validation_0-rmse:0.480735
# [495]	validation_0-rmse:0.480707
# [496]	validation_0-rmse:0.480455
# [497]	validation_0-rmse:0.480344
# [498]	validation_0-rmse:0.480226
# [499]	validation_0-rmse:0.480069
# [500]	validation_0-rmse:0.479984
# [501]	validation_0-rmse:0.479933
# [502]	validation_0-rmse:0.47988
# [503]	validation_0-rmse:0.479744
# [504]	validation_0-rmse:0.479686
# [505]	validation_0-rmse:0.479559
# [506]	validation_0-rmse:0.479326
# [507]	validation_0-rmse:0.479149
# [508]	validation_0-rmse:0.479145
# [509]	validation_0-rmse:0.479047
# [510]	validation_0-rmse:0.478944
# [511]	validation_0-rmse:0.478942
# [512]	validation_0-rmse:0.478853
# [513]	validation_0-rmse:0.478715
# [514]	validation_0-rmse:0.478692
# [515]	validation_0-rmse:0.478558
# [516]	validation_0-rmse:0.478473
# [517]	validation_0-rmse:0.47838
# [518]	validation_0-rmse:0.478357
# [519]	validation_0-rmse:0.478276
# [520]	validation_0-rmse:0.478122
# [521]	validation_0-rmse:0.478003
# [522]	validation_0-rmse:0.477974
# [523]	validation_0-rmse:0.477985
# [524]	validation_0-rmse:0.477952
# [525]	validation_0-rmse:0.477967
# [526]	validation_0-rmse:0.477957
# [527]	validation_0-rmse:0.477875
# [528]	validation_0-rmse:0.47776
# [529]	validation_0-rmse:0.47766
# [530]	validation_0-rmse:0.477594
# [531]	validation_0-rmse:0.477543
# [532]	validation_0-rmse:0.47742
# [533]	validation_0-rmse:0.477322
# [534]	validation_0-rmse:0.477244
# [535]	validation_0-rmse:0.477182
# [536]	validation_0-rmse:0.477148
# [537]	validation_0-rmse:0.477135
# [538]	validation_0-rmse:0.47713
# [539]	validation_0-rmse:0.476983
# [540]	validation_0-rmse:0.477022
# [541]	validation_0-rmse:0.477026
# [542]	validation_0-rmse:0.477018
# [543]	validation_0-rmse:0.476957
# [544]	validation_0-rmse:0.476953
# [545]	validation_0-rmse:0.476924
# [546]	validation_0-rmse:0.476769
# [547]	validation_0-rmse:0.476704
# [548]	validation_0-rmse:0.476606
# [549]	validation_0-rmse:0.476519
# [550]	validation_0-rmse:0.476433
# [551]	validation_0-rmse:0.476265
# [552]	validation_0-rmse:0.476155
# [553]	validation_0-rmse:0.476105
# [554]	validation_0-rmse:0.476074
# [555]	validation_0-rmse:0.476043
# [556]	validation_0-rmse:0.475999
# [557]	validation_0-rmse:0.476036
# [558]	validation_0-rmse:0.476022
# [559]	validation_0-rmse:0.475981
# [560]	validation_0-rmse:0.47588
# [561]	validation_0-rmse:0.475842
# [562]	validation_0-rmse:0.475821
# [563]	validation_0-rmse:0.475816
# [564]	validation_0-rmse:0.475787
# [565]	validation_0-rmse:0.475742
# [566]	validation_0-rmse:0.475722
# [567]	validation_0-rmse:0.475691
# [568]	validation_0-rmse:0.475673
# [569]	validation_0-rmse:0.475602
# [570]	validation_0-rmse:0.475466
# [571]	validation_0-rmse:0.475468
# [572]	validation_0-rmse:0.475429
# [573]	validation_0-rmse:0.475424
# [574]	validation_0-rmse:0.47522
# [575]	validation_0-rmse:0.475157
# [576]	validation_0-rmse:0.475039
# [577]	validation_0-rmse:0.474968
# [578]	validation_0-rmse:0.474593
# [579]	validation_0-rmse:0.474573
# [580]	validation_0-rmse:0.474552
# [581]	validation_0-rmse:0.474519
# [582]	validation_0-rmse:0.474521
# [583]	validation_0-rmse:0.474526
# [584]	validation_0-rmse:0.474225
# [585]	validation_0-rmse:0.474214
# [586]	validation_0-rmse:0.474211
# [587]	validation_0-rmse:0.474027
# [588]	validation_0-rmse:0.473968
# [589]	validation_0-rmse:0.473922
# [590]	validation_0-rmse:0.473912
# [591]	validation_0-rmse:0.473881
# [592]	validation_0-rmse:0.473857
# [593]	validation_0-rmse:0.473813
# [594]	validation_0-rmse:0.47373
# [595]	validation_0-rmse:0.473637
# [596]	validation_0-rmse:0.473604
# [597]	validation_0-rmse:0.473599
# [598]	validation_0-rmse:0.473573
# [599]	validation_0-rmse:0.473573
# XGBRegressor(max_depth=5, min_child_weight=47, n_estimators=600,
#              objective='reg:squarederror', reg_alpha=10.0, subsample=0.9963,
#              verbosity=0)

# %%
# Usamos estos modelos para predecir las caracteristicas para un nuevo modelo
def ensemble_model(data_set):
  dnn_y_hat = dnn_model.predict(data_set)
  xgb_y_hat = xgb_model.predict(data_set)

  dnn_y_hat = dnn_y_hat.reshape(len(dnn_y_hat),)

  X_global =  pd.DataFrame({'Dnn_predict':dnn_y_hat, 
                            'Xgboost_predict': xgb_y_hat})
  X_global['Dnn_predict'] = X_global['Dnn_predict'].where(X_global['Dnn_predict'] >0, 0)
  X_global['Xgboost_predict'] = X_global['Xgboost_predict'].where(X_global['Xgboost_predict'] >0, 0)
  return X_global

# %%
X_global = ensemble_model(X_tr)
X_global
# Out:
#         Dnn_predict  Xgboost_predict
# 0          0.257431         0.000000
# 1          0.169561         0.000000
# 2          0.215348         0.000000
# 3          0.271430         0.406273
# 4          0.275013         0.000000
# ...             ...              ...
# 356395     3.232460         6.214194
# 356396     1.868192         4.823900
# 356397     7.384979         7.714790
# 356398     1.582748         1.186668
# 356399     3.811234         3.363756
#
# [356400 rows x 2 columns]

# %%
# Se usan las predicciones anteriores para generar el nuevo modelo
global_model = RandomForestRegressor(random_state = 0)
global_model.fit(X_global, y_tr)

X_test_ensemble = ensemble_model(X_test)
y_hat = global_model.predict(X_test_ensemble)

# %%
# Generamos la predicción global 
sub['sales'] = np.exp(y_hat) - 1
sub['sales'] = sub['sales'].where(sub['sales']>0, 0)
sub.to_csv('submission.csv', index=False)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

X_global = ensemble_model(X_val)
y_hat = global_model.predict(X_global)

mae = mean_absolute_error(y_val, y_hat)
mse = mean_squared_error(y_val, y_hat)
r2_scor = r2_score(y_val, y_hat)

# %%
print('MAE score: %.3f' % mae)
print('MSE score: %.3f' % mse)
print('R2 score: %.3f' % r2_scor)
# Out:
# MAE score: 0.356
# MSE score: 0.252
# R2 score: 0.961
